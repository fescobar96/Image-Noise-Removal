# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import tensorflow as tf
from skimage.util import random_noise

# %%
def add_noise():
  img = cv2.imread('/content/drive/My Drive/natural-images/natural_images/flower/flower_0842.jpg')
  noise_img = random_noise(img, mode='s&p',amount=0.3)
  noise_img = np.array(255*noise_img, dtype = 'uint8')
  plt.imshow(noise_img)

# %%
original_images = '/content/drive/My Drive/natural-images/natural_images/flower'

# %%
for file in tqdm(sorted(os.listdir(original_images))):
  print(file)
# Out:
# 100%|██████████| 843/843 [00:00<00:00, 11051.72it/s]
# flower_0000.jpg
# flower_0001.jpg
# flower_0002.jpg
# flower_0003.jpg
# flower_0004.jpg
# flower_0005.jpg
# flower_0006.jpg
# flower_0007.jpg
# flower_0008.jpg
# flower_0009.jpg
# flower_0010.jpg
# flower_0011.jpg
# flower_0012.jpg
# flower_0013.jpg
# flower_0014.jpg
# flower_0015.jpg
# flower_0016.jpg
# flower_0017.jpg
# flower_0018.jpg
# flower_0019.jpg
# flower_0020.jpg
# flower_0021.jpg
# flower_0022.jpg
# flower_0023.jpg
# flower_0024.jpg
# flower_0025.jpg
# flower_0026.jpg
# flower_0027.jpg
# flower_0028.jpg
# flower_0029.jpg
# flower_0030.jpg
# flower_0031.jpg
# flower_0032.jpg
# flower_0033.jpg
# flower_0034.jpg
# flower_0035.jpg
# flower_0036.jpg
# flower_0037.jpg
# flower_0038.jpg
# flower_0039.jpg
# flower_0040.jpg
# flower_0041.jpg
# flower_0042.jpg
# flower_0043.jpg
# flower_0044.jpg
# flower_0045.jpg
# flower_0046.jpg
# flower_0047.jpg
# flower_0048.jpg
# flower_0049.jpg
# flower_0050.jpg
# flower_0051.jpg
# ...

# %%
'/content/drive/My Drive/natural-images/natural_images/flower/flower_0842.jpg'
# Out:
# '/content/drive/My Drive/natural-images/natural_images/flower/flower_0842.jpg'

# %%
image = tf.keras.preprocessing.image.load_img(original_images + '/' + 'flower_0842.jpg', target_size=(256,256))

# %%
plt.imshow(image)

# %%
image.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-1c83375060d0> in <module>()
# ----> 1 image.shape
#
# AttributeError: 'Image' object has no attribute 'shape'
