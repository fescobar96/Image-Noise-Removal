# %%
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import os
import tensorflow as tf
from skimage.util import random_noise
from PIL import Image

# %%
def add_noise(image_path, noise):
  image = cv2.imread(image_path)
  image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
  return random_noise(image, mode='s&p',amount=noise)

# %%
original_images = '/content/drive/My Drive/natural-images/natural_images/flower'

# %%
for noise in tqdm([0.1, 0.25, 0.5]):
  for file in os.listdir(original_images):
    image = add_noise(original_images + '/' + file, noise)
    image = Image.fromarray(image)
    im.save('/content/drive/My Drive/natural-images/natural_images/noisy_flower' + '/' + str(noise) + '/' file)
# Out:
#  34%|███▎      | 284/843 [02:08<03:40,  2.53it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-104-25d30420968b> in <module>()
#       1 for file in tqdm(sorted(os.listdir(original_images))):
# ----> 2   plt.imshow(add_noise(original_images + '/' + file, 0.5))
#
# <ipython-input-103-b02e17b0cb1d> in add_noise(image_path, noise)
#       1 def add_noise(image_path, noise):
# ----> 2   image = cv2.imread(image_path)
#       3   image = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       4   return random_noise(image, mode='s&p',amount=noise)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x7f417cb8d6a8> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
